# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# If I was an American-Steryotype-Asisan-Parents, What data I would intestest me?

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# #### Extra information for better understanding
# 1) ACT vs. SAT: How to Decide Which Test to Take:
# https://www.usnews.com/education/best-colleges/articles/act-vs-sat-how-to-decide-which-test-to-take#:~:text=Broken%20down%20by%20test%20components,and%2035%2Dminute%20science%20test.
#
# Quick recap:
# - In the class of 2020, SAT test-takers: 2.2 million || ACT test-takers: 1.7 million
# - More and more students in the last five to 10 years are taking both.
# - There is ACT optional writing test which fewer test-takers from the class of 2020 took the optional writing portions
# - SAT costs 52 USD and ACT costs 55 USD (70 USD if the optional writing test is included)
# - Additional fees may apply for other options, such as late registration. Students may also be able to take the SAT or ACT for free thanks to state support or fee waivers.
#
# 2) States That Provide A Free ACT/ SAT Test:
# https://www.collegeraptor.com/getting-in/articles/act-sat/states-act-sat-given-free/
#
# Quick recap:
# - Michigan
# - Connecticut
# - New York
# - Delaware
# - Idaho
# - New Hampshire
# - Illinois
# - Colorado (SAT is free for juniors/public schools)
# - Columbia (not really requied in the state itself)
# - Maine (optional and offered free of charge)
# - Rhode Island (not required ,but free for juniors)
# - Arizona, Minnesota, Tennessee, Florida, Texas, and Maryland (a few schools or districts can administer the SAT exam)
#
# 3) Cost of Living in each states: https://advisorsmith.com/data/coli/ \
# 4) 2020,2021 SAT score infomation: https://www.bestcolleges.com/blog/how-to-get-perfect-sat-score/

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# ---

# %% [markdown]
# ### The datasets that will be used in this projects
# These two datasets below are the main datasets, since my objective is to explore about best school
# - 2019 SAT Scores by Intended College Major
# - Ranges of Accepted ACT & SAT Student Scores by Colleges
#
# Datasets below are for statistical references
# - 2019 SAT Scores by State
# - 2019 ACT Scores by State
# - 2018 SAT Scores by State
# - 2018 ACT Scores by State
# - 2017 SAT Scores by State
# - 2017 ACT Scores by State

# %% [markdown]
# ---

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def mean(values):
    """ This function is used to find mean value """
    return sum(values) / len(values)

# %% [markdown]
# <font color='Blue'> Nailed it! </font></font>

# %% [markdown]
# ---

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def sd(values):
    """ This function is used to find standard deviation """
    n = len(values)
    mean = sum(values) / n
    var = sum((x - mean)**2 for x in values) / n
    std = var ** 0.5
    return std

# %% [markdown]
# <font color='Blue'> Nailed it again! </font></font>

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
def percent_to_flaot(values):
    """This function is used to turn string into float
       when the strings are in this format "50%, 30.5%, etc."
    """
    return float(values.strip('%')) / 100.0

# %% [markdown]
# <font color='Blue'> Hat tricks nailing! </font></font>

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Import important libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display_html

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# Read in csv files for EDA

icm = pd.read_csv('../data/sat_2019_by_intended_college_major.csv')
sac = pd.read_csv('../data/sat_act_by_college.csv')
sat_19 = pd.read_csv('../data/sat_2019.csv')
act_19 = pd.read_csv('../data/act_2019.csv')
sat_18 = pd.read_csv('../data/sat_2018.csv')
act_18 = pd.read_csv('../data/act_2018.csv')
sat_17 = pd.read_csv('../data/sat_2017.csv')
act_17 = pd.read_csv('../data/act_2017.csv')
cost   = pd.read_csv('../data/advisorsmith_cost_of_living_index.csv')

# %%
# Checking null in all dataframes
print(icm.isnull().sum())
print('')
print(sac.isnull().sum())
print('')
print(sat_19.isnull().sum())
print('')
print(sat_18.isnull().sum())
print('')
print(sat_17.isnull().sum())
print('')
print(act_19.isnull().sum())
print('')
print(act_18.isnull().sum())
print('')
print(act_17.isnull().sum())
print('')
print(cost.isnull().sum())
# Out:
# IntendedCollegeMajor    0
# TestTakers              0
# Percent                 0
# Total                   0
# ReadingWriting          0
# Math                    0
# dtype: int64
#
# School                             0
# Test Optional?                     0
# Applies to Class Year(s)          26
# Policy Details                     0
# Number of Applicants               0
# Accept Rate                        0
# SAT Total 25th-75th Percentile     0
# ACT Total 25th-75th Percentile     0
# dtype: int64
#
# State                 0
# Participation Rate    0
# EBRW                  0
# Math                  0
# Total                 0
# dtype: int64
#
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64
#
# State                                 0
# Participation                         0
# ...

# %% [markdown]
# <font color = 'red'>!!! sat_act_by_college.csv: 26 null !!!</font>

# %%
sac.shape
# Out:
# (416, 8)

# %%
loss =(26/416)*100
print(f'The percentage of data loss is: {loss}%')
# Out:
# The percentage of data loss is: 6.25%

# %%
# Explore problematic column
sac.groupby(['Applies to Class Year(s)']).nunique()
# Out:
#                           School  Test Optional?  Policy Details  \
# Applies to Class Year(s)
# 2021                         196               4             172
# 2021 2022                     11               2              11
# 2021 2022 2023                15               1              15
# 2021 2022 2023 2024            9               2               4
# 2021 2022 2023 2024 2025       1               1               1
# All / Permanent Policy       158               3             158
#
#                           Number of Applicants  Accept Rate  \
# Applies to Class Year(s)
# 2021                                       196          166
# 2021 2022                                   11           11
# 2021 2022 2023                              15           15
# 2021 2022 2023 2024                          9            9
# 2021 2022 2023 2024 2025                     1            1
# All / Permanent Policy                     156          137
#
# ...

# %%
# Decided to fill null with 2021 (mode value)
sac['Applies to Class Year(s)'] = sac['Applies to Class Year(s)'].replace(np.nan,2012)
sac.isnull().sum()
# Out:
# School                            0
# Test Optional?                    0
# Applies to Class Year(s)          0
# Policy Details                    0
# Number of Applicants              0
# Accept Rate                       0
# SAT Total 25th-75th Percentile    0
# ACT Total 25th-75th Percentile    0
# dtype: int64

# %% [markdown]
# ---

# %%
# Find out column with mismatch type of the data
print(icm.info())
print('')
print(sac.info())
print('')
print(sat_19.info())
print('')
print(sat_18.info())
print('')
print(sat_17.info())
print('')
print(act_19.info())
print('')
print(act_18.info())
print('')
print(act_17.info())
print('')
print(cost.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   IntendedCollegeMajor  38 non-null     object
#  1   TestTakers            38 non-null     object
#  2   Percent               38 non-null     object
#  3   Total                 38 non-null     int64
#  4   ReadingWriting        38 non-null     int64
#  5   Math                  38 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 1.9+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416 entries, 0 to 415
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   School                          416 non-null    object
#  1   Test Optional?                  416 non-null    object
#  2   Applies to Class Year(s)        416 non-null    object
# ...

# %%
# Changing data type to appropriate type
icm['Percent'] = icm['Percent'].apply(percent_to_flaot)*100
icm['TestTakers'] = icm['TestTakers'].str.replace(',','')
icm['TestTakers'] = icm['TestTakers'].astype(float)
sac['Accept Rate'] = sac['Accept Rate'].apply(percent_to_flaot)*100
sat_19['Participation Rate'] = sat_19['Participation Rate'].str.replace('—','0',regex=True)
sat_19['Participation Rate'] = sat_19['Participation Rate'].apply(percent_to_flaot)*100
sat_18['Participation'] = sat_18['Participation'].str.replace('—','0',regex=True)
sat_18['Participation'] = sat_18['Participation'].apply(percent_to_flaot)*100
sat_17['Participation'] = sat_17['Participation'].str.replace('—','0',regex=True)
sat_17['Participation'] = sat_17['Participation'].apply(percent_to_flaot)*100
act_19['Participation'] = act_19['Participation'].str.replace('—','0',regex=True)
act_19['Participation'] = act_19['Participation'].apply(percent_to_flaot)*100
act_18['Participation'] = act_18['Participation'].str.replace('—','0',regex=True)
act_18['Participation'] = act_18['Participation'].apply(percent_to_flaot)*100
act_17['Participation'] = act_17['Participation'].str.replace('—','0',regex=True)
act_17['Participation'] = act_17['Participation'].apply(percent_to_flaot)*100
act_17.drop(['English','Math','Reading','Science'], axis=1, inplace=True)
act_17['Composite'] = act_17['Composite'].str.replace('x','0',regex=True)
act_17['Composite'] = act_17['Composite'].astype(float)

# %%
# Chaning column names to lower-case
icm.set_axis(['college_major', 'test_takers', 'percent', 'total', 'read_write', 'math'], axis=1, inplace=True)
sac.set_axis(['school', 'test_opt', 'batch', 'policy_details', 'num_of_applicants', 
              'accept_rate', 'sat_25th_75th_pct', 'act_25th_75th_pct'], axis=1, inplace=True)
sat_19.set_axis(['state', 'par_rate', 'ebrw', 'math', 'total'], axis=1, inplace=True)
sat_18.set_axis(['state', 'par_rate', 'ebrw', 'math', 'total'], axis=1, inplace=True)
sat_17.set_axis(['state', 'par_rate', 'ebrw', 'math', 'total'], axis=1, inplace=True)
act_19.set_axis(['state', 'par_rate', 'comp'], axis=1, inplace=True)
act_18.set_axis(['state', 'par_rate', 'comp'], axis=1, inplace=True)
act_17.set_axis(['state', 'par_rate', 'comp'], axis=1, inplace=True)
cost.set_axis(['city', 'state', 'cost'], axis=1, inplace=True)

# %%
# Merge dataframes for easier data comparing

# SAT SCORE 2019,2018,2017 
sat_merge_x = sat_19.merge(sat_18, right_on = 'state', left_on = 'state')
sat_merge_final = sat_merge_x.merge(sat_17, right_on = 'state', left_on = 'state')

# ACT SCORE 2019,2018,2017 
act_merge_x = act_19.merge(act_18, right_on = 'state', left_on = 'state')
act_merge_final = act_merge_x.merge(act_17, right_on = 'state', left_on = 'state')

# %%
sat_merge_final.head()
# Out:
#         state  par_rate_x  ebrw_x  math_x  total_x  par_rate_y  ebrw_y  \
# 0     Alabama         7.0     583     560     1143         6.0     595
# 1      Alaska        41.0     556     541     1097        43.0     562
# 2     Arizona        31.0     569     565     1134        29.0     577
# 3    Arkansas         6.0     582     559     1141         5.0     592
# 4  California        63.0     534     531     1065        60.0     540
#
#    math_y  total_y  par_rate  ebrw  math  total
# 0     571     1166       5.0   593   572   1165
# 1     544     1106      38.0   547   533   1080
# 2     572     1149      30.0   563   553   1116
# 3     576     1169       3.0   614   594   1208
# 4     536     1076      53.0   531   524   1055

# %%
act_merge_final.head()
# Out:
#         state  par_rate_x  comp_x  par_rate_y  comp_y  par_rate  comp
# 0     Alabama       100.0    18.9       100.0    19.1     100.0  19.2
# 1      Alaska        38.0    20.1        33.0    20.8      65.0  19.8
# 2     Arizona        73.0    19.0        66.0    19.2      62.0  19.7
# 3    Arkansas       100.0    19.3       100.0    19.4     100.0  19.4
# 4  California        23.0    22.6        27.0    22.7      31.0  22.8

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**college_major**|object| 2019 SAT by Intended college major |List of College Major|
# |**test_takers**|float64||Number of Test-takers who enrolled in that major
# |**percent**|float64||Percentage of Test-takers enrolled in that major
# |**total**|int64||Total Test-takers enrolled in that major|
# |**read_write**|int64||Mean score in Reading and Writing section|
# |**math**|int64||Mean score in Math section|
# |---|---|---|---|
# |**school**|object|Ranges of Accepted ACT & SAT Student Scores by Colleges|Name of school |
# |**test_opt**|object||srt Yes or No for required or not required test score|
# |**batch**|object||Student apply for following batch|
# |**policy_details**|object||Details from each school about requirement and admission|
# |**num_of_applicants**|int64||Number of applicants in certain school|
# |**accept_rate**|float64||The percentage that certain school will accept a person as their freshmen |
# |**sat_25th_75th_pct**|object||Range of SAT score 25th Percentile-75th Percentile (eg.1xxx-1xxx)|
# |**act_25th_75th_pct**|object||Range of ACT score 25th Percentile-75th Percentile (eg.1xxx-1xxx)|
# |---|---|---|---|
# |**state**|object|2019 SAT Scores by State, 2018 SAT Scores by State, 2017 SAT Scores by State|Certain State in United States of America|
# |**par_rate**|float64||Percentage of participation of students in certain state|
# |**ebrw**|int64||Evidence-Based Reading and Writing score in each state|
# |**math**|int64||Math score in each state|
# |**total**|int64||Total score from EBRW and Math part in each state|
# |---|---|---|---|
# |**state**|object|2019 ACT Scores by State, 2018 ACT Scores by State, 2017 ACT Scores by State |Certain state in United States of America|
# |**par_rate**|float64||Percentage of participation of student in each state|
# |**comp**|float64||Total score including English, Math, Reading, and Science section in each state|
# |---|---|---|---|
# |**city**|object|Cost of living index|Certain name of the city in each state|
# |**state**|object||Certain name of the state|
# |**cost**|float64||Cost of living index of certain city|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
# Set new data set to be embeded in html 
icm_n    = icm.describe().round(2)
sac_n    = sac.describe().round(2)
cost_n   = cost.describe().round(2)
sat_19_n = sat_19.describe().round(2)
act_19_n = act_19.describe().round(2)
sat_18_n = sat_18.describe().round(2)
act_18_n = act_18.describe().round(2)
sat_17_n = sat_17.describe().round(2)
act_17_n = act_17.describe().round(2)

# Set caption and style
icm_n_styler = icm_n.style.set_table_attributes("style='display:inline'").set_caption('IntendedCollegeMajor2019')
sac_n_styler = sac_n.style.set_table_attributes("style='display:inline'").set_caption('ScoreAcceptedByCollege')
cost_n_styler = cost_n.style.set_table_attributes("style='display:inline'").set_caption('Cost of Living Index')
sat_19_n_styler = sat_19_n.style.set_table_attributes("style='display:inline'").set_caption('SAT 2019')
act_19_n_styler = act_19_n.style.set_table_attributes("style='display:inline'").set_caption('ACT 2019')
sat_18_n_styler = sat_18_n.style.set_table_attributes("style='display:inline'").set_caption('SAT 2018')
act_18_n_styler = act_18_n.style.set_table_attributes("style='display:inline'").set_caption('ACT 2018')
sat_17_n_styler = sat_17_n.style.set_table_attributes("style='display:inline'").set_caption('SAT 2017')
act_17_n_styler = act_17_n.style.set_table_attributes("style='display:inline'").set_caption('ACT 2017')

# %%
# Display them along side each other for easy observation
display_html(icm_n_styler._repr_html_() + sac_n_styler._repr_html_(), raw=True);
# College admission scores
# Out:
# <style type="text/css">
# </style>
# <table id="T_e84c3" style='display:inline'>
#   <caption>IntendedCollegeMajor2019</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e84c3_level0_col0" class="col_heading level0 col0" >test_takers</th>
#       <th id="T_e84c3_level0_col1" class="col_heading level0 col1" >percent</th>
#       <th id="T_e84c3_level0_col2" class="col_heading level0 col2" >total</th>
#       <th id="T_e84c3_level0_col3" class="col_heading level0 col3" >read_write</th>
#       <th id="T_e84c3_level0_col4" class="col_heading level0 col4" >math</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e84c3_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_e84c3_row0_col0" class="data row0 col0" >38.000000</td>
#       <td id="T_e84c3_row0_col1" class="data row0 col1" >38.000000</td>
#       <td id="T_e84c3_row0_col2" class="data row0 col2" >38.000000</td>
# ...

# %%
# SAT and ACT scores
display_html(sat_19_n_styler._repr_html_()+act_19_n_styler._repr_html_()+\
             sat_18_n_styler._repr_html_()+act_18_n_styler._repr_html_()+\
             sat_17_n_styler._repr_html_()+act_17_n_styler._repr_html_()+\
             cost_n_styler._repr_html_(), raw=True);
# Out:
# <style type="text/css">
# </style>
# <table id="T_6f51a" style='display:inline'>
#   <caption>SAT 2019</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f51a_level0_col0" class="col_heading level0 col0" >par_rate</th>
#       <th id="T_6f51a_level0_col1" class="col_heading level0 col1" >ebrw</th>
#       <th id="T_6f51a_level0_col2" class="col_heading level0 col2" >math</th>
#       <th id="T_6f51a_level0_col3" class="col_heading level0 col3" >total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f51a_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_6f51a_row0_col0" class="data row0 col0" >53.000000</td>
#       <td id="T_6f51a_row0_col1" class="data row0 col1" >53.000000</td>
#       <td id="T_6f51a_row0_col2" class="data row0 col2" >53.000000</td>
#       <td id="T_6f51a_row0_col3" class="data row0 col3" >53.000000</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Comparing statistic data in SAT and ACT 2017, 2018, and 2019
# - One state data is missing from ACT(count)
# - SAT mean = 1106.53 - 1126.1 is equivalent to 21-22 in ACT.\
#   ACT mean ≈ 21 is equivalent to 1060~1090 in SAT.
#     - <font color = 'blue'>SAT and ACT have almost the same level of mean value. </font>
# - SAT min = 935-977 is equivalent to 17-18 in ACT.\
#   ACT min ≈ 18 is equivalent to 960-980 in SAT.
#     - <font color = 'green'>SAT and ACT have almost the same level of min value. </font>
#     - except in 2017 which min value = 2.3 (Someone didn't read enough textbooks)
# - SAT max = 1284 - 1295 is equivalent to 27 in ACT.\
#   ACT max ≈ 25 is equivalent to 1200-1220 in SAT.
#     - <font color = 'red'> SAT has higher level of max value than ACT.</font>

# %% [markdown]
# ---

# %%
# assign standard deviation to dictionary
sd = {}
sd_1 = round(icm.drop('college_major',axis=1).std(),2).to_dict()
sd_2 = round(sac.drop(['school','test_opt','batch','policy_details','sat_25th_75th_pct','act_25th_75th_pct'], axis=1).std(),2).to_dict()
sd_3 = round(sat_merge_final.drop('state',axis=1).std(),2).to_dict()
sd_4 = round(act_merge_final.drop('state',axis=1).std(),2).to_dict()

sd = {**sd_1,**sd_2,**sd_3,**sd_4}

# %% [markdown]
# <font size=5px color = 'blue'><b><u> Investigation </u></b></font>

# %% [markdown]
# ### [1] Acceptable score

# %%
sat_merge_final.describe()
# Out:
#        par_rate_x      ebrw_x      math_x      total_x  par_rate_y  \
# count   51.000000   51.000000   51.000000    51.000000   51.000000
# mean    49.058824  560.803922  552.196078  1113.078431   45.745098
# std     38.747600   46.248035   51.290553    97.197910   37.314256
# min      2.000000  483.000000  460.000000   943.000000    2.000000
# 25%      5.500000  527.500000  511.500000  1038.000000    4.500000
# 50%     54.000000  550.000000  546.000000  1097.000000   52.000000
# 75%     82.000000  612.000000  599.000000  1210.000000   77.500000
# max    100.000000  636.000000  648.000000  1284.000000  100.000000
#
#            ebrw_y      math_y      total_y    par_rate        ebrw  \
# count   51.000000   51.000000    51.000000   51.000000   51.000000
# mean   563.686275  556.235294  1120.019608   39.803922  569.117647
# std     47.502627   47.772623    94.155083   35.276632   45.666901
# min    480.000000  480.000000   977.000000    2.000000  482.000000
# ...

# %%
# Calculation 
ASD = round((97.19+94.16+92.49)/3,2)
AMS = round((1113.08+1120.02+1126.09)/3,2)
AMAX = round((1284+1298+1295)/3,2)

# Average Standard Deviation from each year
print(f'Average Standard Deviation: {ASD}')
# Average Mean score from each year
print(f'Average Mean Score:         {AMS}')
# Average Max score from each year
print(f'Average Max Score:          {AMAX}')

# My son/daughter must be a star of education field
accept_1 = round(AMS+(3*ASD),2)
accept_2 = round(AMS+(2*ASD),2)
accept_3 = round(AMS+ASD,2)
accept_4 = round(AMS+(ASD/2),2)
accept_5 = round(AMS, 2)
print('')
print(f'{accept_1}: good')
print(f'{accept_2}: acceptble')
print(f'{accept_3}: study harder ')
print(f'{accept_4}: disgrace to ancestors ')
print(f'{accept_5}: I am not your father ')
# Out:
# Average Standard Deviation: 94.61
# Average Mean Score:         1119.73
# Average Max Score:          1292.33
#
# 1403.56: good
# 1308.95: acceptble
# 1214.34: study harder
# 1167.04: disgrace to ancestors
# 1119.73: I am not your father

# %% [markdown]
# ### [2] Acceptable major for my kids

# %%
icm.sort_values(by='test_takers', ascending=False).head(5)
# Out:
#                                         college_major  test_takers  percent  \
# 14   Health Professions and related Clinical Sciences     331026.0     18.0
# 4   Business, Management, Marketing, and Related S...     221523.0     12.0
# 9                                         Engineering     194127.0     11.0
# 3                  Biological and Biomedical Sciences     155834.0      8.0
# 35                Visual and Performing Arts, General     130642.0      7.0
#
#     total  read_write  math
# 14   1048         529   518
# 4    1072         534   537
# 9    1139         559   581
# 3    1139         572   566
# 35   1045         536   510

# %% [markdown]
# Acceptable majors will be
# - Health Care field
# - Business
# - Enginerring
# - Biomedical Sciences
# - and not Art

# %% [markdown]
# ### [3] Acceptable school

# %%
sac.sort_values(by='accept_rate', ascending=True).head(10)
# Out:
#                                   school  test_opt                   batch  \
# 0                    Stanford University       Yes                    2021
# 1                        Harvard College       Yes                    2021
# 2                   Princeton University       Yes                    2021
# 3                    Columbia University       Yes                    2021
# 4                        Yale University       Yes                    2021
# 5     California Institute of Technology  Yes (TB)               2021 2022
# 6  Massachusetts Institute of Technology       Yes                    2021
# 7                       Brown University       Yes                    2021
# 8                  University of Chicago       Yes  All / Permanent Policy
# 9                         Pomona College       Yes                    2021
#
#                                       policy_details  num_of_applicants  \
# ...

# %% [markdown]
# Acceptable university will be
# - Standford University
# - Harvard College
# - Princeton University
# - Columbia University
# - Yale University
# - California Institure of Techonology
# - MIT
# - and no no no

# %% [markdown]
# ### [4] Cost of living

# %%
# Cost of living index
# Normal index = 100
mean = cost['cost'].mean()
std = cost['cost'].std()
max_cost = cost['cost'].max()

print(f'Cost of living index (mean): {round(mean)} = normal')
print(f'Cost of living index (1sd): {round(mean+std,2)} = aight')
print(f'Cost of living index (2sd): {round(mean+(2*std),2)} = getting hard')
print(f'Cost of living index (3sd): {round(mean+(3*std),2)} = strunggling')
print(f'Cost of living index (max): {round(max_cost,2)} = i am dead')
print('')

CA = cost[cost['state'].str.contains("CA")]
CA_mean = round(CA['cost'].mean(),2)
print(f'Cost of living in California:    {CA_mean}')
MA = cost[cost['state'].str.contains("MA")]
MA_mean = round(MA['cost'].mean(),2)
print(f'Cost of living in Massachusetts: {MA_mean}')
NJ = cost[cost['state'].str.contains("NJ")]
NJ_mean = round(NJ['cost'].mean(),2)
print(f'Cost of living in New Jersey:    {NJ_mean}')
NY = cost[cost['state'].str.contains("NY")]
NY_mean = round(NY['cost'].mean(),2)
print(f'Cost of living in New York:      {NY_mean}')
CT = cost[cost['state'].str.contains("CT")]
CT_mean = round(CT['cost'].mean(),2)
print(f'Cost of living in Connecticut:   {CT_mean}')
# Out:
# Cost of living index (mean): 97 = normal
# Cost of living index (1sd): 109.98 = aight
# Cost of living index (2sd): 123.43 = getting hard
# Cost of living index (3sd): 136.87 = strunggling
# Cost of living index (max): 178.6 = i am dead
#
# Cost of living in California:    125.75
# Cost of living in Massachusetts: 114.55
# Cost of living in New Jersey:    103.4
# Cost of living in New York:      97.04
# Cost of living in Connecticut:   108.56

# %% [markdown]
# ### [5] Suitable State for my kids

# %%
# Find SAT score equal or greater than 1237.81 (mean+1.3SD)
sat_19.sort_values(by='total', ascending=False).head(9)

# Find ACT score equal or greater than 24.17  (mean+1.25SD)
act_19.sort_values(by='comp', ascending=False).head(9)

# Set new data set to be embeded in html 
sort_sat    = sat_19.sort_values(by='par_rate', ascending=False).head(20)
sort_act    = act_19.sort_values(by='par_rate', ascending=False).head(20)

# Set caption and style
sort_sat_styler = sort_sat.style.set_table_attributes("style='display:inline'").set_caption('SAT')
sort_act_styler = sort_act.style.set_table_attributes("style='display:inline'").set_caption('ACT')

# Display them along side each other for easy observation
display_html(sort_sat_styler._repr_html_() + '&emsp;' + sort_act_styler._repr_html_(), raw=True);
# Out:
# <style type="text/css">
# </style>
# <table id="T_2a96e" style='display:inline'>
#   <caption>SAT</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a96e_level0_col0" class="col_heading level0 col0" >state</th>
#       <th id="T_2a96e_level0_col1" class="col_heading level0 col1" >par_rate</th>
#       <th id="T_2a96e_level0_col2" class="col_heading level0 col2" >ebrw</th>
#       <th id="T_2a96e_level0_col3" class="col_heading level0 col3" >math</th>
#       <th id="T_2a96e_level0_col4" class="col_heading level0 col4" >total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a96e_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_2a96e_row0_col0" class="data row0 col0" >Colorado</td>
#       <td id="T_2a96e_row0_col1" class="data row0 col1" >100.000000</td>
#       <td id="T_2a96e_row0_col2" class="data row0 col2" >518</td>
#       <td id="T_2a96e_row0_col3" class="data row0 col3" >506</td>
# ...

# %% [markdown]
# Now I got lists of high participation rate which might indicate state support or fee waivers which I can start to find jobs from states in the list.

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
sns.heatmap(icm.corr())
plt.title('Correlation of Intended College Major');

# %%
plt.figure(figsize=(10,5))
plt.hist(sat_19['total'],alpha=0.8)
plt.hist(sat_18['total'],alpha=0.8)
plt.hist(sat_17['total'],alpha=0.8)
plt.legend(labels= ["2019","2018", "2017"])
plt.title('SAT Total score 2019, 2018, and 2017')
# vertical line x= SAT score (mean+sd)
plt.axvline(x=1207.52, color='r', ls='--')
# vertical line x= SAT score (mean+1.30sd)
plt.axvline(x=1237.81, color='b', ls='--')
# vertical line x= SAT score (mean)
plt.axvline(x=1106.53, color='black', ls='--');

# %%
plt.figure(figsize=(10,5))
plt.hist(act_19['comp'],alpha=0.8)
plt.hist(act_18['comp'],alpha=0.8)
plt.hist(act_17['comp'],alpha=0.8)
plt.legend(labels= ["2019","2018", "2017"])
plt.title('ACT Total score 2019, 2018, and 2017')
# vertical line x= ACT score (mean+sd)
plt.axvline(x=23.63, color='r', ls='--')
# vertical line x= ACT score (mean+1.25sd)
plt.axvline(x=24.17, color='b', ls='--')
# vertical line x= ACT score (mean)
plt.axvline(x=21.45, color='black', ls='--');

# %% [markdown]
# By looking at distribution of the data, it looks like there are two group of the students

# %%
sns.boxplot(act_19['comp']);
sns.boxplot(act_18['comp']);
sns.boxplot(act_17['comp']);
plt.title('Boxplot of ACT Total Score')
plt.xlabel('Total Score');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,5))
sns.boxplot(cost['cost']);
plt.title('Cost of living index in USA')
plt.xlabel('Cost of Living index');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data=sac, x="accept_rate", y="num_of_applicants", hue="batch");
sns.regplot(data=sac, x="accept_rate", y="num_of_applicants")
plt.xlabel('Accept Rate')
plt.ylabel('Number of Applicants')
plt.title('Accept Rate vs. Number of Applicant')
# Out:
# Text(0.5, 1.0, 'Accept Rate vs. Number of Applicant')

# %%
plt.figure(figsize=(10,15))
# vertical line x= Cost of living index (mean+2sd)
plt.axvline(x=123.43, color='r') 
plt.title('')
sns.histplot(data=cost, x="cost", y="state");

# %% [markdown]
# The cost of living of some cities in eight states goes beyond 2SD which are
# - New York
# - California
# - Massachusetts
# - Washington
# - Montana
# - Colorado
# - Florida
# - Hawaii.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **To-Do:** *Edit this cell with your conclusions and recommendations.*

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
